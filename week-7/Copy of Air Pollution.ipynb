# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Data Analytics/week-7/Air_Quality_data.csv", encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ed9cf1219654> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/drive/MyDrive/Data Analytics/week-7/Air_Quality_data.csv", encoding='latin-1')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
df.isna()
# Out:
#         stn_code  sampling_date  state  location  agency   type    so2    no2  \
# 0          False          False  False     False    True  False  False  False
# 1          False          False  False     False    True  False  False  False
# 2          False          False  False     False    True  False  False  False
# 3          False          False  False     False    True  False  False  False
# 4          False          False  False     False    True  False  False  False
# ...          ...            ...    ...       ...     ...    ...    ...    ...
# 435737     False          False  False     False   False  False  False  False
# 435738     False          False  False     False   False  False  False  False
# 435739      True           True  False      True    True   True   True   True
# 435740      True           True  False      True    True   True   True   True
# 435741      True           True  False      True    True   True   True   True
#
# ...

# %%
df.isna().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# %%
df.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date', 'year'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# year                                7
# dtype: int64

# %%
df.describe()
# Out:
#                  so2            no2           rspm            spm  \
# count  401096.000000  419509.000000  395520.000000  198355.000000
# mean       10.829414      25.809623     108.832784     220.783480
# std        11.177187      18.503086      74.872430     151.395457
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000      14.000000      56.000000     111.000000
# 50%         8.000000      22.000000      90.000000     187.000000
# 75%        13.700000      32.200000     142.000000     296.000000
# max       909.000000     876.000000    6307.033333    3380.000000
#
#              pm2_5           year
# count  9314.000000  435735.000000
# mean     40.791467    2009.534123
# std      30.832525       4.791559
# min       3.000000    1987.000000
# 25%      24.000000    2007.000000
# 50%      32.000000    2010.000000
# 75%      46.000000    2013.000000
# max     504.000000    2015.000000

# %%
df = df.drop('agency', axis=1)
df
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
# ...

# %%
df.dtypes
# Out:
# stn_code                               object
# sampling_date                          object
# state                                  object
# location                               object
# type                                   object
# so2                                   float64
# no2                                   float64
# rspm                                  float64
# spm                                   float64
# location_monitoring_station            object
# pm2_5                                 float64
# date                           datetime64[ns]
# year                                  float64
# dtype: object

# %%
median_value = df['rspm'].median()
df['rspm'].fillna(median_value, inplace=True)

# %%
print("DataFrame after replacing null values with the median:")
print(df.head())
# Out:
# DataFrame after replacing null values with the median:
#   stn_code       sampling_date           state   location  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4  90.0  NaN
# 1                     Industrial Area  3.1   7.0  90.0  NaN
# 2  Residential, Rural and other Areas  6.2  28.5  90.0  NaN
# 3  Residential, Rural and other Areas  6.3  14.7  90.0  NaN
# 4                     Industrial Area  4.7   7.5  90.0  NaN
#
#   location_monitoring_station  pm2_5       date    year
# 0                         NaN    NaN 1990-02-01  1990.0
# 1                         NaN    NaN 1990-02-01  1990.0
# ...

# %%
median_value = df['spm'].median()
df['spm'].fillna(median_value, inplace=True)

# %%
print("DataFrame after replacing null values with the median:")
print(df.head())
# Out:
# DataFrame after replacing null values with the median:
#   stn_code       sampling_date           state   location  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad
#
#                                  type  so2   no2  rspm    spm  \
# 0  Residential, Rural and other Areas  4.8  17.4  90.0  187.0
# 1                     Industrial Area  3.1   7.0  90.0  187.0
# 2  Residential, Rural and other Areas  6.2  28.5  90.0  187.0
# 3  Residential, Rural and other Areas  6.3  14.7  90.0  187.0
# 4                     Industrial Area  4.7   7.5  90.0  187.0
#
#   location_monitoring_station  pm2_5       date    year
# 0                         NaN    NaN 1990-02-01  1990.0
# 1                         NaN    NaN 1990-02-01  1990.0
# ...

# %%
median_value = df['pm2_5'].median()
df['pm2_5'].fillna(median_value, inplace=True)

# %%
print("DataFrame after replacing null values with the median:")
print(df.head())
# Out:
# DataFrame after replacing null values with the median:
#   stn_code       sampling_date           state   location  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad
#
#                                  type  so2   no2  rspm    spm  \
# 0  Residential, Rural and other Areas  4.8  17.4  90.0  187.0
# 1                     Industrial Area  3.1   7.0  90.0  187.0
# 2  Residential, Rural and other Areas  6.2  28.5  90.0  187.0
# 3  Residential, Rural and other Areas  6.3  14.7  90.0  187.0
# 4                     Industrial Area  4.7   7.5  90.0  187.0
#
#   location_monitoring_station  pm2_5       date    year
# 0                         NaN   32.0 1990-02-01  1990.0
# 1                         NaN   32.0 1990-02-01  1990.0
# ...

# %%
median_value = df['so2'].median()
df['so2'].fillna(median_value, inplace=True)

# %%
print("DataFrame after replacing null values with the median:")
print(df.head())
# Out:
# DataFrame after replacing null values with the median:
#   stn_code       sampling_date           state   location  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad
#
#                                  type  so2   no2  rspm    spm  \
# 0  Residential, Rural and other Areas  4.8  17.4  90.0  187.0
# 1                     Industrial Area  3.1   7.0  90.0  187.0
# 2  Residential, Rural and other Areas  6.2  28.5  90.0  187.0
# 3  Residential, Rural and other Areas  6.3  14.7  90.0  187.0
# 4                     Industrial Area  4.7   7.5  90.0  187.0
#
#   location_monitoring_station  pm2_5       date    year
# 0                         NaN   32.0 1990-02-01  1990.0
# 1                         NaN   32.0 1990-02-01  1990.0
# ...

# %%
median_value = df['no2'].median()
df['no2'].fillna(median_value, inplace=True)

# %%
print("DataFrame after replacing null values with the median:")
print(df.head())
# Out:
# DataFrame after replacing null values with the median:
#   stn_code       sampling_date           state   location  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad
#
#                                  type  so2   no2  rspm    spm  \
# 0  Residential, Rural and other Areas  4.8  17.4  90.0  187.0
# 1                     Industrial Area  3.1   7.0  90.0  187.0
# 2  Residential, Rural and other Areas  6.2  28.5  90.0  187.0
# 3  Residential, Rural and other Areas  6.3  14.7  90.0  187.0
# 4                     Industrial Area  4.7   7.5  90.0  187.0
#
#   location_monitoring_station  pm2_5       date    year
# 0                         NaN   32.0 1990-02-01  1990.0
# 1                         NaN   32.0 1990-02-01  1990.0
# ...

# %%
df.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# type                             5393
# so2                                 0
# no2                                 0
# rspm                                0
# spm                                 0
# location_monitoring_station     27491
# pm2_5                               0
# date                                7
# year                                7
# dtype: int64

# %%
columns_to_drop_null = ['sampling_date', 'location', 'date', 'year']
df.dropna(subset=columns_to_drop_null, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# stn_code                       144074
# sampling_date                       0
# state                               0
# location                            0
# type                             5390
# so2                                 0
# no2                                 0
# rspm                                0
# spm                                 0
# location_monitoring_station     27488
# pm2_5                               0
# date                                0
# year                                0
# dtype: int64

# %%
df['type']
# Out:
# 0         Residential, Rural and other Areas
# 1                            Industrial Area
# 2         Residential, Rural and other Areas
# 3         Residential, Rural and other Areas
# 4                            Industrial Area
#                          ...
# 435734                                 RIRUO
# 435735                                 RIRUO
# 435736                                 RIRUO
# 435737                                 RIRUO
# 435738                                 RIRUO
# Name: type, Length: 435735, dtype: object

# %%
df['stn_code'].head()
# Out:
# 0    150.0
# 1    151.0
# 2    152.0
# 3    150.0
# 4    151.0
# Name: stn_code, dtype: object

# %%
df.isnull().sum()
# Out:
# stn_code                       144074
# sampling_date                       0
# state                               0
# location                            0
# type                             5390
# so2                                 0
# no2                                 0
# rspm                                0
# spm                                 0
# location_monitoring_station     27488
# pm2_5                               0
# date                                0
# year                                0
# dtype: int64

# %%
df['type'].unique()
# Out:
# array(['Residential, Rural and other Areas', 'Industrial Area', nan,
#        'Sensitive Area', 'Industrial Areas', 'Residential and others',
#        'Sensitive Areas', 'Industrial', 'Residential', 'RIRUO',
#        'Sensitive'], dtype=object)

# %%
rec_val = df['type'].mode().iloc[0]

# %%
rec_val
# Out:
# 'Residential, Rural and other Areas'

# %%
df['type'].fillna('Residential, Rural and other Areas', inplace=True)

# %%
df['type'].unique()
# Out:
# array(['Residential, Rural and other Areas', 'Industrial Area',
#        'Sensitive Area', 'Industrial Areas', 'Residential and others',
#        'Sensitive Areas', 'Industrial', 'Residential', 'RIRUO',
#        'Sensitive'], dtype=object)

# %%
column_to_change = 'type'
replacement_mapping = {
    'Residential, Rural and other Areas': 'Residential Area',
    'Residential and others': 'Residential Area',
    'Residential': 'Residential Area',
    'Industrial Areas': 'Industrial Area',
    'Industrial': 'Indistrial Area',
    'Sensitive': 'Sensitive Area',
    'Sensitive Areas': 'Sensitive Area'
}

# %%
df[column_to_change] = df[column_to_change].replace(replacement_mapping)

# %%
df['type'].unique()
# Out:
# array(['Residential Area', 'Industrial Area', 'Sensitive Area',
#        'Indistrial Area', 'RIRUO'], dtype=object)

# %%
df.isnull().sum()
# Out:
# stn_code                       144074
# sampling_date                       0
# state                               0
# location                            0
# type                                0
# so2                                 0
# no2                                 0
# rspm                                0
# spm                                 0
# location_monitoring_station     27488
# pm2_5                               0
# date                                0
# year                                0
# dtype: int64

# %%
df['location_monitoring_station'].unique()
# Out:
# array([nan, 'C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, Hyderabad',
#        'Uppal, Modern Foods & Industries IDA, Hyderabad',
#        'Jublee Hills Hyderabad', 'Paradise, Hyderabad',
#        'Charminar, Hyderabad',
#        'Industrial Estate, Marripalem, Visakhapatnam',
#        'Panchayat Raj office, Mindi, Visakhapatnam',
#        'Police Barracks, Visakhapatnam',
#        'INS-Virabahu, Naval Area, Visakhapatnam',
#        'Seethammadhara, Visakhapatnam', 'C.I.T.D. Balanagar', 'Nacharam',
#        'Uppal', 'ABIDS Circle', 'Charminar', 'Jubilee Hills', 'Paradise',
#        'Tarnaka', 'Reg.Science Centre', 'Benz Circle',
#        'Industrial Estate', 'Panchayat Raj Office', 'Police Barracks',
#        'Seethammadhara', 'INS-VIRBAHU', 'Zoo Park', 'Mourya Inn',
#        'Police Station', 'RTC Bus Depot', 'Autonagar', 'Ganapuram Area',
#        'Hindu College Guntur', 'RO APPCB', 'Venkatareddy Nagar',
#        'CWMP, RAMKY', 'Pedagantyada V', 'KUDA Office',
# ...

# %%
column_to_change = 'location_monitoring_station'
replacement_value = 'unknown'

# %%
df[column_to_change].fillna(replacement_value, inplace=True)

# %%
df.isnull().sum()
# Out:
# stn_code                       144074
# sampling_date                       0
# state                               0
# location                            0
# type                                0
# so2                                 0
# no2                                 0
# rspm                                0
# spm                                 0
# location_monitoring_station         0
# pm2_5                               0
# date                                0
# year                                0
# dtype: int64

# %%
output_file = '/content/drive/MyDrive/week7.csv'
df.to_csv(output_file, index=False)
